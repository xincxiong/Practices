# %%
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import *

# %%
RUN_NAME = "run 2 with 5 nodes"

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# %%
# Define the model
model = Sequential()
model.add(Dense(5, input_dim=9, activation='relu', name='layer_1'))
model.add(Dense(100, activation='relu', name='layer_2'))
model.add(Dense(50, activation='relu', name='layer_3'))
model.add(Dense(1, activation='linear', name='output_layer'))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Create a TensorBoard logger
logger = keras.callbacks.TensorBoard(
    log_dir='logs/{}'.format(RUN_NAME),
    histogram_freq=0,
    batch_size=32,

    write_graph=True
)

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2,
    callbacks=[logger]
)

# %%
# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

# %%
# use pre-trained model to recognize image
import numpy as np
from keras.preprocessing import image
from keras.applications import xception,inception_v3,mobilenet,resnet50
# from keras.utils import plot_model
# from keras.utils.vis_utils import model_to_dot
# import pydot
# from IPython.display import SVG
# Out:
# /home/xin/miniconda2/envs/machinelearning/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Load Keras' ResNet50 model that was pre-trained against the ImageNet database
# model1 = xception.Xception()
# model2=inception_v3.InceptionV3(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)

# %%
from keras.applications import resnet50
model3=resnet50.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)

# %%
model3.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 55, 55, 64)   0           activation_1[0][0]
# ...

# %%
# Load the image file, resizing it to 224x224 pixels (required by this model)
img = image.load_img("bay.JPG", target_size=(224, 224))

# Convert the image to a numpy array
x = image.img_to_array(img)
y=image.img_to_array(img)

# plot_model(model,to_file='model.png')



# SVG(model_to_dot(model).create(prog='dot',format='svg'))

# %%
from scipy.misc import imshow,imsave,imread

# %%
a=imread('bay.JPG')
# Out:
# /home/xin/miniconda2/envs/machinelearning/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib.pyplot as plt
imshow(a)
plt.show()
# Out:
# /home/xin/miniconda2/envs/machinelearning/lib/python2.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imshow` is deprecated!
# `imshow` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``matplotlib.pyplot.imshow`` instead.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-0bb1e57623fe> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 imshow(a)
#       3 plt.show()
#
# /home/xin/miniconda2/envs/machinelearning/lib/python2.7/site-packages/numpy/lib/utils.pyc in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# ...

# %%
x.shape

# %%
#model.summary()
# Add a forth dimension since Keras expects a list of images
x = np.expand_dims(x, axis=0)

# Scale the input image to the range used in the trained network
# x1 = xception.preprocess_input(x)
x2=resnet50.preprocess_input(x)

# %%
x2.shape

# %%
# Run the image through the deep neural network to make a prediction
# predictions1 = model1.predict(x1)
predictions2 = model3.predict(x2)
# print(predictions.shape)

# Look up the names of the predicted classes. Index zero is the results for the first image.
# predicted_classes1 = xception.decode_predictions(predictions1, top=9)
predicted_classes2 = resnet50.decode_predictions(predictions2, top=9)
# print(len(predicted_classes))
# print(predicted_classes)

# model1.summary()

# plot_model(model1,to_file='model.png')
# SVG(model_to_dot(model1).create(prog='dot',format='svg'))


print("This is an image of xception:")

for imagenet_id1, name1, likelihood1 in predicted_classes2[0]:
    print(" - {}: {:2f} likelihood".format(name1, likelihood1))
print()

'''
from keras.utils import plot_model
plot_model(model1, to_file='model.png')



print('----------------------------------------------------------------')

print("This is an image of resnet50:")

for imagenet_id2, name2, likelihood2 in predicted_classes2[0]:
    print(" - {}: {:2f} likelihood".format(name2, likelihood2))
print()
'''
# Out:
# This is an image of xception:
#  - fountain: 0.950368 likelihood
#  - solar_dish: 0.008120 likelihood
#  - bannister: 0.006349 likelihood
#  - suspension_bridge: 0.004119 likelihood
#  - traffic_light: 0.003465 likelihood
#  - stage: 0.002798 likelihood
#  - window_shade: 0.001767 likelihood
#  - greenhouse: 0.001719 likelihood
#  - radiator: 0.001250 likelihood
# ()
# '\nfrom keras.utils import plot_model\nplot_model(model1, to_file=\'model.png\')\n\n\n\nprint(\'----------------------------------------------------------------\')\n\nprint("This is an image of resnet50:")\n\nfor imagenet_id2, name2, likelihood2 in predicted_classes2[0]:\n    print(" - {}: {:2f} likelihood".format(name2, likelihood2))\nprint()\n'
